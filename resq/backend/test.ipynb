# %%
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import google.generativeai as genai
from langchain_community.vectorstores import FAISS
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.question_answering import load_qa_chain
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFDirectoryLoader

# %%
load_dotenv()
os.getenv("GOOGLE_API_KEY")
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
def read_doc(directory):
    file_loader=PyPDFDirectoryLoader(directory)
    documents=file_loader.load()
    return documents

# %%
docs = read_doc('documents/')
type(docs)
# Out:
# list

# %%
def chunk_data(docs, chunk_size = 100, chunk_overlap=50):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    doc = text_splitter.split_documents(docs)
    return doc

# %%
document_list=chunk_data(docs)
document_list
# Out:
# [Document(page_content='Chapter-7 \n \nFIRE PROTECTION AND FIRE SAFETY \nREQUIREMENTS \n \n7.1  SCOPE', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='This part covers the requirements of the fire protection for the multi-storeyed buildings (high', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='rise buildings) and th e buildings, which are of 15 m.  and above in height and low', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='occupancies of categories such as Assembly, Institutional., Educational (more than two storeyed and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='Educational (more than two storeyed and built-up area exceeds 1000 sq m)., Business (where plot', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='area exceeds 1000 sq m)., Business (where plot area exceeds 500 sq m.), Mercantile (where aggregate', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='exceeds 500 sq m.), Mercantile (where aggregate covered area exceeds 750 sq m.), Hotel, Hospital,', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='covered area exceeds 750 sq m.), Hotel, Hospital, Nursing', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='Homes, Underground Complexes,  Industrial Storage, Meeti ng / Banquet Halls, Hazardous', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='Occupancies.  \n \n7.2  PROCEDURE FOR CLEARANCE FROM FIRE SERVICE', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='a) The concerned Authority shall refer the building plans to the Chief Fire', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='Officer for obtaining clearance in respect of building identified in clause 7.1', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='of these Bye-Laws.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='b)  The Authority shall furnish three se ts of complete build ing plans along with', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='prescribed fee to the Chief Fire Officer,  after ensuring that the proposals are in', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='line with Master Plan/Zonal Plan of the area.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='c)  The plans shall be clearly marked a nd indicate the complete fire protection', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='arrangements and the means of access/es cape for the proposed building with', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='suitable legend along with standard si gns and symbols on the drawings. The', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='same shall be duly signed/certified by a licensed Fire Consultant/Architect. The information', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='Fire Consultant/Architect. The information regarding fire safety measures shall be furnished as per', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='fire safety measures shall be furnished as per', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='Annexure ‘D’ along with details.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='d)  The Chief Fire Officer shall examine these plans to ensure that they are in', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='accordance with the provisions of fire sa fety and means of escape as per these', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='bye- laws and shall forward two sets of plans duly signed for implementation', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='to the building sanctioning Authority.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='e)  After completion of fire fighting inst allations as approved and duly tested and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='certified by the licensed Fire Consultant / Architect, the Owner/ Builder of the building shall', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='the Owner/ Builder of the building shall approach the Chief Fire Officer through the concerned', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='the Chief Fire Officer through the concerned Authority for obtaining clea rance from fire safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='for obtaining clea rance from fire safety and means of escape point', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='of view. The concerned Authority shall en sure that clearance from Chief Fire', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='Officer has been obtained for the bu ilding identified in clause 7.1 before', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='granting the completion certificate.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='f) On receipt of the above request, the Chief Fire Officer shall issue the No', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='Objection Certificate from fire safety and means of escape point of view after', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='satisfying himself that the entire fire protection measures are implemented and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='functional as per approved plans.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='g) Any deficiencies observed during the course of inspection shall be', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='communicated to the Authority for rectif ication and a copy of the same shall', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='be forwarded to the concerne d building owner /builder.  \n \n7.3  RENEWAL OF FIRE CLEARANCE', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='On the basis of undertaking given by the Fire Consultant / Architect, the Chief Fire Officer', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='shall renew the fire clearance in respect of the following buildings on annual basis:-', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='1)  Public entertainment and assembly  \n2)  Hospitals  \n3)  Hotels', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='2)  Hospitals  \n3)  Hotels  \n4)  Under ground shopping complex  \n \n \n \nModel Building-Bye-laws', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='Model Building-Bye-laws  \n 101', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='7.4 FEE  \n \na)  For augmentation of fire service faci lities for effecting rescue/fire fighting', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='operation in high rise build ing, fee payable to Chief Fire Officer by the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='applicant(s) along with sets  of plans for obtaining th e No Objection Certificate', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='shall be as prescribed by the Authority.  \n \n7.5 FIRE CONSULTANT', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='The Architect of the project wi ll be responsible for making pr ovisions for fire protection and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='fire fighting measure as provided in this Chapte r and for that she / he may consult an expert', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='in this field, as in case of other professionals for struct ural, sanitary and others.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='7.6  TERMINOLOGY', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='For the purpose of this Chapter all the technica l terms shall have the meaning as defined in', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='National Building Code of India,  Part-IV, Fire Protection as amended from time to time but', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='for the terms which are defined otherwise in these bye-Laws.  \n \n7.7 GENERAL', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='The Chief Fire Officer may insist on suitable provisions in the building from fire safety and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='means of escape point of view depending on th e occupancy, height or on account of new', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='developments creating special fire hazard, in addition to the provision of these building bye', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='laws and part IV (Fire Protection) of National Building Code of India  \n \n7.8 MEANS OF ACCESS', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='7.8 MEANS OF ACCESS  \n \nAs provided in Building Bye-Laws 4.7.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='7.8.1 Provisions of Exterior Open Spaces around the Building : As provided in building', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='bye laws 4.9.4. \nModel Building-Bye-laws  \n 102', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9 EXIT REQUIREMENT  \n \nAs provided in Building Bye-Laws 4.8.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.1 Type of Exits:  As provided in Building Bye-Laws 4.8.1', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.2 Number of Size of Exits: As provided in Building Bye-Laws 4.8.2', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.3 Arrangements of Exits:  As provided in Building Bye-Laws 4.8.3', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.4 Occupant Load: As provided in Building Bye-Laws 4.1', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.5 Capacity of Exit:  As provided in Building Bye-Laws 4.8.4', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.6 Staircase Requirements:  As provided in Building Bye-Laws 4.8.5', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.7 Minimum Width Provision for Stairways: As provided in Building Bye-Laws 4.8.6', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.8 Minimum Width Provision for Passageway/Corridors: As provided in Building Bye-\nLaws 4.8.7', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='Laws 4.8.7  \n7.9.9  Doorways: As provided in Building Bye-Laws 4.8.8', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.10 Stairways:  As provided in Building Bye-Laws 4.8.9', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='7.9.11  Fire Escapes or External Stairs:', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='a) Fire escape shall not be taken in to account while calculating the number of', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='staircases for a building.  \nb) All fire escapes shall be directly connected to the ground.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='c) Entrance to the fire escape shall be separate and remote from internal \nstaircase.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='staircase. \nd) The route to fire escape shall be free of obstructions at all times except the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='doorway leading to the fire escape which shall have the required fire \nresistance.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='resistance. \ne) Fire escape shall be construc ted of non-combustible materials.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='f) Fire escape stairs shall have straight flight not less than 125 cm wide with 25', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='cm treads and risers not more than 19 cm.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='g) Handrails shall be at a height not less than 100 cm.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='h) Fire escape staircase in the mercantil e, business, assembly, hotel buildings', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='above 24 m. height shall be a fire tower and in such a case width of the same shall not be less', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='such a case width of the same shall not be less than the width of the main staircase.   No', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='less than the width of the main staircase.   No combustible material', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='shall be allowed in the fire tower. \nModel Building-Bye-laws  \n 103', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='7.9.12 Spiral Stairs', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='a) The use of spiral staircase shall be limited to low occupant load and to a', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='building height 9 m.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='b) A spiral stair shall not be less than 150 cm in diameter and shall be designed', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='to give the adequate headroom.  \n7.9.13 Staircase Enclosures', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='a) The external enclosing walls of the stai rcase shall be of the brick or the R.C.C.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='construction having fire resistance of not  less than two hours. All enclosed', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='staircases shall have access through self-closing door of one-hour fire', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='resistance.  These shall be single swi ng doors opening in the direction of the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='escape.  The door shall be fitted wi th the check action door closers.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='b) The staircase enclosures on the external wall of the building shall be', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='ventilated to the atmosphere at each landing.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='c) Permanent vent at the top equal to th e 5% of the cross sectional area of the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='enclosure and openable sashes at each floor  level with area equal to 1 to 15%', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='of the cross sectional area of the encl osure on external shall be provided.  The', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='roof of the shaft shall be at least 1 m. above the surrounding roof. There shall', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='be no glazing or the glass bric ks in any internal closing wall of staircase. If the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='staircase is in the core of the building and cannot be ventilated at each', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='landing, a positive of 5-mm. w.g. by an el ectrically operate d blower/blowers', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='shall be maintained.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='d) The mechanism for pressurizing the stai rcase shaft shall be so installed that', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='the same shall operate automatically on fire alarm system/sprinkler system', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='and be provided with manual operation facilities.  \n7.9.14   Ramps', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='7.9.14   Ramps  \na)  Ramps of slope of not more than 1 in 10 may be substituted for and shall', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='comply with all the applicable requirem ents of all required stairways as to', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='enclosure capacity and limiting dimensi ons. Larger slopes shall be provided', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='for special uses but in no case greater th an 1 in 8. For all slopes exceeding 1 in', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='10 and where the use is such as to invol ve danger of slipping, the ramp shall', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='be surfaced with approved non-slipping material.  \nModel Building-Bye-laws  \n 104', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='b)  The minimum width of the ramps in th e Hospitals shall be 2.4 m. and in the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='basement using car parking shall be 6.0 m.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='c)  Handrails shall be provided on both sides of the ramp.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='d)  Ramp shall lead directly  to outside open space at ground level or courtyards of \nsafe place.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='safe place.  \ne) For building above 24.0 m. in height, access to ramps from any floor of the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='building shall be through smoke fire check door.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='f) In case of nursing homes, hospitals etc.  area exceeding 300 sq m. at each floor', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='one of the exit facility sh all be a ramp of not less than 2.4 m. in width.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='7.10  PROVISION OF LIFTS', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='a) Provision of the lifts shall be made for all multi-storeyed building having a', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='height of 15.0 m. and above.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='b) All the floors shall be accessible for 24 hrs. by the lift. The lift provided in the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='buildings shall not be considered as a means of escap e in case of emergency.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='c) Grounding switch at ground floor level to enable the fire service to ground the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='lift car in case of emergenc y shall also be provided.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='d)  The lift machine room shall be separate and no other machinery be installed in \nit.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='it. \n7.10.1  Lift Enclosure/lift   \nGeneral requirements shall be as follows', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='a) Walls of lift enclosures shall have a fire rating of tw o hours.  Lift shafts shall', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='have a vent at the top of area not less than 0.2 sq m.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='b) Lift motor room shall be located pref erably on top of the shaft and separated', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='from the shaft by the floor of the room.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='c) Landing door in lift enclosures shall have  a fire resistance of not less than one \nhour.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='hour.  \nd) The number of lifts in one lift bank sh all not exceed four. A wall of two hours', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='fire rating shall separate i ndividual shafts in a bank.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='e) Lift car door shall have a fi re resistance rating of 1 hour.  \nModel Building-Bye-laws  \n 105', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='f) For buildings 15.0 m. and above in he ight, collapsible gates shall not be', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='permitted for lifts and solid doors with fire resistance of at least one hour shall \nbe provided.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='be provided. \ng) If the lift shaft and lobby is in the core of the building a positive pressure', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='between 25 and 30 pa shall be maintained  in the lobby and a possible pressure', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='of 50 pa shall be maintained in the lift shaft. The mechanism for the pressurization shall act', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='The mechanism for the pressurization shall act automatically with  the fire alarm/sprinkler system', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='with  the fire alarm/sprinkler system and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='it shall be possible to operate this mechanically also.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='h) Exit from the lift lobby, if located in the core of the building, shall be through', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='a self-closing fire smoke check door  of one-hour fire resistance.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='i) Lift shall not normally communicate w ith the basement. If however, lifts are', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='in communication, the lift lobby of the base ment shall be pressurized as in (g)', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='with self closing door as in (h).', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='j) Grounding switch (es), at ground floor level shall be provided to enable the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='fire service to ground the lifts.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='k) Telephone/talk back communication facilities may be provided in lift cars for', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='communication system and lifts shall be c onnected to the fire  control room of \nthe building.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='the building.  \nl) Suitable arrangements such as providi ng slope in the floor of the lift lobby', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='shall be made to prevent water used during fire fighting, etc at any landing', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='from entering the lift shafts.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='m) A sign shall be posted and maintained  on every floor at or near the lift', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='indicating that in case of fire, occupant s shall use the stairs unless instructed', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='otherwise. The sign shall also contai n a plan for each floor showing the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='location of the stairways. Floor marki ng shall be done at each floor on the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='wall in front of the lift-landing door.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='n) Alternate power supply shall be provided in all the lifts.  \n \n7.10.2  Fire Lift', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='Following details shall apply for a fire lif t in addition to above requirements:', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='Model Building-Bye-laws  \n 106', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='a)  To enable fire service personnel to  reach the upper floors with the minimum', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='delay, one or more of the lifts shall be so  designed so as to be available for the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='exclusive use of the fireman in an em ergency and be directly accessible to', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='every dwelling/lettable fl oor space on each floor.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='b) The lift shall have a floor area of not  less than 1.4 sq.mt. It shall have a', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='loading capacity of not less than 545 kg. (8 persons lift)  with automatic \nclosing doors.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='closing doors.  \nc) The electric supply shal l be on a separate service from electric supply mains', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='in a building and the cables run in a route safe from fire, that is within a lift', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='shaft. Lights and fans in the elevator  having wooden paneling or sheet steel', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='construction shall be ope rated on 24-volt supply.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='d) In case of failure of normal electri c supply, it shall auto matically switchover', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='to the alternate supply. Fo r apartment houses, this changeover of supply could', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='be done through manually operated change over switch. Alternatively, the lift', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='should be so wired that in case of pow er failure, it comes down at the ground', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='level and comes to stand still with door open.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='e) The operation of a fire  lift shall by a single toggle of two-button switch', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='situated in a glass-fronted box adjacent to the lift at the en trance level. When', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='the switch is on landing; call points will become inoperative and the lift will', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='be on car control only or on a priority c ontrol device. When the switch is off,', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='the lift will return to normal working. This lift can be used by the occupants in \nnormal times.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content="normal times.  \nf) The words 'F1RE LIFT' shall be cons picuously displayed in fluorescent paint", metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='on the lift landing doors at each floor level.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='g) The speed of the fire lift shall be such  that it can reach to  the top floor from', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='ground level within one minute.  \n \n \n7.11 BASEMENT', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='7.11 BASEMENT  \n \nAs provided in Chapter- 3 and Building Bye-Laws 4.5.5', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='Model Building-Bye-laws  \n 107', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='7.11.1 Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='i) The access to the basement shall be eith er from the main or alternate staircase', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='providing access and exit from higher floor s. Where the staircase is continue', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='the same shall be enclosed type servi ng as a fire separation from the basement', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='floor and higher floors. Open ramps shall be permitted if they are constructed', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='within the building line subject to the provision of the (iv).', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='ii) In case of basement for office, suffi cient number of exit ways and access ways', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='shall be provided with a travel distance not more than 15.0 m.  The travel distance in case of', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='more than 15.0 m.  The travel distance in case of dead-end shall be 7.5 m.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='iii) The basement shall be partitioned an d in no case compartment shall be more', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='than 500 sq m. and less than 50 sq m. area except parking. Each compartment shall have ventilation', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='parking. Each compartment shall have ventilation st andards as laid down in Bye-Laws separately and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='andards as laid down in Bye-Laws separately and', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='independently. The partition shall be ma de in consultation with Chief Fire \nOfficer.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='Officer.  \niv)   The first basement (immediately  below ground level) can be used for', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='services/parking/other permissible se rvices. Lower basement, if provided,', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='shall exclusively be used  for car parking only.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='v) Each basement shall be separately ventilated. Vents with cross-sectional area', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='(aggregate) not less than 2.5 percent of the floor area spread evenly round the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='perimeter of the basement shall be provide d in the form of grills or breakable', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='starboard lights or pavement lights or by way of shafts. Alte rnatively a system', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='of air inlets shall be provided at basement floor level and smoke outlets at basement ceiling', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='floor level and smoke outlets at basement ceiling level. Inlets and extracts may be terminated at', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='level. Inlets and extracts may be terminated at ground level with starboard or pavement lights as', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='ground level with starboard or pavement lights as be fore. But ducts to convey fresh air to', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='the basement floor level have to be la id. Starboard and pavement lights should', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='be in positions easily accessible to the firemen and clearly marked "SMOKE OUTLET" or AIR INLET"', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='and clearly marked "SMOKE OUTLET" or AIR INLET" with an indicat ion of area served at or near the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='opening.  \nvi) The staircase of basement shall be of enclosed type having fire resistance of', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='not less than two hours and shall be situat ed at the periphery of the basement', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='to be entered at ground level only from the open air and in such positions that', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='Model Building-Bye-laws  \n 108', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='smoke from any fire in the basement shall not obstruct any exit serving the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='ground and upper stories of the build ing and shall co mmunicate with', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='basement through a lobby provi ded with fire resisting self closing door of one', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='hour rating. In case of basement being used as car parking only, the travel', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='distance shall be 45 m.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='vii) In multi-storeyed basements, intake duct may serve all basements levels, but', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='each basement and basement compartment shall have separate smoke outlet duct or ducts.  Mechanical', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='separate smoke outlet duct or ducts.  Mechanical extractors for smoke venting system from lower', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='basement levels shall also be provided. The system shall be of such design as', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='to operate on actuation of smoke, heat sensitive detectors/sprinklers, if installed, and shall have', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='if installed, and shall have a considerably superior performance compared to the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='standard units. It shall also have an arrangement to start it manually.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='viii) Mechanical extractors shall have an internal locking arrangement so that', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='extractors shall continue to operate and supply fans shall stop automatically with the actuation of', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='shall stop automatically with the actuation of fire detectors. Mech anical extractors shall be', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='fire detectors. Mech anical extractors shall be designed to', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='permit 30 air changes per hour in case of fire or distress call.  However, for', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='normal operation, only 30 air changes or any other convenient factor can be \nmaintained.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='maintained.  \nix) Mechanical extractors shall have an alternate source  of power supply.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='x) Ventilating ducts shall be integrated w ith the structure and made out of brick', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='masonry or RCC as far as possible and wh en this duct crosses the transformer', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='area of electrical switchboard, fi re dampers shall be provided.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='xi) Kitchens working on gas fuel shall not be permitted in basement/sub-\nbasement.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='basement.  \nxii) If cutouts are provided from basement to the upper floors or to the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='atmosphere, all side cutout openings in the basements shall be protected by sprinkler heads at', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='shall be protected by sprinkler heads at closed spacing so as to  form a water curtain in the event', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='so as to  form a water curtain in the event of a', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='fire.  \nxiii) Dewatering pump shall be provided in all basements.  \n \n \nModel Building-Bye-laws', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='Model Building-Bye-laws  \n 109', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}),
#  Document(page_content='Chapter-7                                                         Fire Protection and Fire Safety', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='Fire Protection and Fire Safety Requirements', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='7.12  PROVISION OF HELIPAD', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='All high-rise buildings 50 m. and above shall have provision for a Helipad on the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='terrace. The same shall be approved by the Authority.  \n \n7.13 SERVICE DUCTS/REFUGE CHUTE', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='a) Service duct shall be enclosed by wall s and door, if any, of 2 hours fire rating.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='If ducts are larger than 10 sq m. th e floor should seal them, but provide', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='suitable opening for the pipes to pass  through, with the gaps sealed.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='b) A vent opening at the top of the serv ice shaft shall be pr ovided between one-', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='fourth and one-half of the area of the shaf t. Refuge chutes shall have an outlet', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='at least of wall of non-combustible mate rial with fire re sistance of not less', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
#  Document(page_content='than two hours. They shall not be locat ed within the staircase enclosure or', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}),
# ...
#  Document(page_content='modified bywater bodies, land masses and lesser local elements on a smaller scale. Wind can be', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='local elements on a smaller scale. Wind can be compressedunder pressure, expanded and contracted', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='compressedunder pressure, expanded and contracted with heat and cold, made moist or dry and may', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='with heat and cold, made moist or dry and may pause,then gust with violence in any direction.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='It is estimated that one pound of fuel requires 200 cubic feet of air during combustion.  Wind', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='makes more oxygen available to the fire which increases the rate of fuel consumption.  Windsmay', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='increases the rate of fuel consumption.  Windsmay cause fires to jump prepared or natural barriers', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='cause fires to jump prepared or natural barriers or send a fire through tree tops when there', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='or send a fire through tree tops when there islittle understory heat or fuel.  Over areas such as', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='understory heat or fuel.  Over areas such as plains or long, wide valleys, prevailing winddirection', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='or long, wide valleys, prevailing winddirection can be easily predicted throughout the year, but in', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='be easily predicted throughout the year, but in rough topography, wind currents arethrown into', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='in rough topography, wind currents arethrown into confusion as vegetation, large rocks, mountains', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='confusion as vegetation, large rocks, mountains or hills create drag upon windmovements.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='Winds change direction or intensity throughout the day and night with temperature fluctua-', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='tions and local topography.  Large bodies of water such as oceans and lakes, usually cause windsto', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='such as oceans and lakes, usually cause windsto blow inland as the sun warms the land then outward', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='inland as the sun warms the land then outward when the land cools more rapidly than thewater.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='when the land cools more rapidly than thewater.  Winds will blow upward when mountain slopes warm', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='Winds will blow upward when mountain slopes warm under the sunshine and down slopeas the surface', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='under the sunshine and down slopeas the surface cools at night.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='Relative humidity is the relationship between the moisture vapor in the air now and the total it', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='could hold at its present temperature. Air passes over surfaces picking up water vapor until', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='passes over surfaces picking up water vapor until itbecomes saturated and precipitates moisture.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='itbecomes saturated and precipitates moisture.  When it has reached this point, the air has a', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='When it has reached this point, the air has a rela-tive humidity of 100 percent.  Warm air can', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='rela-tive humidity of 100 percent.  Warm air can hold more moisture than cold air.  When the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='can hold more moisture than cold air.  When the relativehumidity descends below 30 percent,', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='the relativehumidity descends below 30 percent, conditions are more favorable for wildfire because', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='are more favorable for wildfire because the aircan absorb more moisture from fuels.  The less', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='aircan absorb more moisture from fuels.  The less moisture in the fuel, the less time is required', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='moisture in the fuel, the less time is required for', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}),
#  Document(page_content='5heat to bring about combustion.  Light fuels such as grass, dead leaves and pine straw lose', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='moisture quickly with changes in humidity.  Heavy fuels such as limbs, logs and tree trunks dryout', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='fuels such as limbs, logs and tree trunks dryout more slowly.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Precipitation is the liquid or solid moisture that falls from the atmosphere. Fuel moisture is', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='affected by the amount and duration of precipitation.  Light fuels are affected more quickly', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Light fuels are affected more quickly thanheavy fuels since they gain and lose moisture usually', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='fuels since they gain and lose moisture usually within one hour.  Heavy fuels are notaffected as', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='within one hour.  Heavy fuels are notaffected as much since they gain or lose moisture more slowly.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='since they gain or lose moisture more slowly.  Green living leaves gain and losemoisture according', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='living leaves gain and losemoisture according to the transpiration habits of their species, so it', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='the transpiration habits of their species, so it is not unusual to see “green”trees burning in a', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='is not unusual to see “green”trees burning in a wildfire.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='A large amount of precipitation in a short time will not raise the fuel moisture as much as', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='lesser rainfall over a longer period of time where the fuels can absorb more moisture before itruns', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='the fuels can absorb more moisture before itruns off.  Moisture in fuel will not burn.  It must be', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='off.  Moisture in fuel will not burn.  It must be converted to steam by heat and driven awaybefore', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='converted to steam by heat and driven awaybefore combustion will take place.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Large fires can make their own weather. Large convection updrafts cause air currents along', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='the ground toward the fire and sometimes cause down drafts beyond the fire perimeter.  Smokeclouds', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='drafts beyond the fire perimeter.  Smokeclouds may shade the sun and alter the temporary radiation', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='shade the sun and alter the temporary radiation of solar heat toward and away fromthe earth.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Fuel\nFuel is any combustible material.  Wildland fuels are basically live and/or dead plant mate-', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='rial.  These vary from one area of the country to another with the ecosystem.  Fuels are important', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='to study in fire management because they are the one component of the fire triangle humans', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='are the one component of the fire triangle humans caninfluence the most.  Wildland fuels are', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='humans caninfluence the most.  Wildland fuels are grouped into four major types based on the', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='are grouped into four major types based on the primary fuelthat carries the fire.  These are grass,', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='fuelthat carries the fire.  These are grass, shrubs, timber litter  and logging slash.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Grass is found in most ecosystems, but it is more dominant as a fuel in desert and range', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='areas.  It can become prevalent after a fire in forested areas.  Fires in grass spread rapidly', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='in forested areas.  Fires in grass spread rapidly butburn out quickly.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Shrubs are also found throughout most areas.  Palmetto and gallberry are highly flammable', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='shrubs in the southeastern United States.  As you go westward, sagebrush and chaparral are', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='As you go westward, sagebrush and chaparral are thehighly ignitable shrubs.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Timber litter is leaves, pine needles, small twigs and limbs you find on the forest floor espe-', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='cially in mountainous areas.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Logging slash is the debris left after timber harvesting or silviculture operations such as', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='pruning, thinning or shrub cutting.  It includes broken understory trees or shrubs, stumps,', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='broken understory trees or shrubs, stumps, bark,branches, chunks or logs.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='Regardless of the type of fuel, fire behavior is dependent on characteristics such as fuel', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}),
#  Document(page_content='6moisture, size and shape, fuel loading, horizontal continuity  and vertical arrangement.   We have', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='discussed the role weather plays in fuel moisture .  Different species have different moisture', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='holding capacity.  Dry fuels, will of course, ignite and burn more easily than the same fuels when', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='they are wet.  As fuel moisture increases, the amount of heat required to ignite and burn that', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='amount of heat required to ignite and burn that fuelalso increases.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='The size and shape of fuels also determine their ability to burn.  Light fuels  which have a', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='diameter of one-half inch or less, dry out quickly, ignite quickly as they are surrounded by', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='quickly, ignite quickly as they are surrounded by plentyof oxygen, burn quickly and are easily', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='by plentyof oxygen, burn quickly and are easily extinguished.  Light fuels  include grasses,', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='extinguished.  Light fuels  include grasses, shrubs, leaves,twigs, and pine needles.  Heavy fuels', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='leaves,twigs, and pine needles.  Heavy fuels  are larger such as limbs, logs and tree trunks which', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='larger such as limbs, logs and tree trunks which dry out', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='more slowly, heat more slowly and usually have bark or some protective mechanism to preventmoisture', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='or some protective mechanism to preventmoisture loss.', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  Document(page_content='Fuel loading refers to the quantity of fuels in an ecosystem.  However, this does not necessar-', metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}),
#  ...]

# %%
new_document_list = []
for i in document_list:
    new_document_list.append(str(i))

# %%
new_document_list
# Out:
# ["page_content='Chapter-7 \\n \\nFIRE PROTECTION AND FIRE SAFETY \\nREQUIREMENTS \\n \\n7.1  SCOPE' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='This part covers the requirements of the fire protection for the multi-storeyed buildings (high' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='rise buildings) and th e buildings, which are of 15 m.  and above in height and low' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='occupancies of categories such as Assembly, Institutional., Educational (more than two storeyed and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='Educational (more than two storeyed and built-up area exceeds 1000 sq m)., Business (where plot' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='area exceeds 1000 sq m)., Business (where plot area exceeds 500 sq m.), Mercantile (where aggregate' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='exceeds 500 sq m.), Mercantile (where aggregate covered area exceeds 750 sq m.), Hotel, Hospital,' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='covered area exceeds 750 sq m.), Hotel, Hospital, Nursing' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='Homes, Underground Complexes,  Industrial Storage, Meeti ng / Banquet Halls, Hazardous' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='Occupancies.  \\n \\n7.2  PROCEDURE FOR CLEARANCE FROM FIRE SERVICE' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='a) The concerned Authority shall refer the building plans to the Chief Fire' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='Officer for obtaining clearance in respect of building identified in clause 7.1' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='of these Bye-Laws.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='b)  The Authority shall furnish three se ts of complete build ing plans along with' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='prescribed fee to the Chief Fire Officer,  after ensuring that the proposals are in' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='line with Master Plan/Zonal Plan of the area.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='c)  The plans shall be clearly marked a nd indicate the complete fire protection' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='arrangements and the means of access/es cape for the proposed building with' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='suitable legend along with standard si gns and symbols on the drawings. The' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='same shall be duly signed/certified by a licensed Fire Consultant/Architect. The information' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='Fire Consultant/Architect. The information regarding fire safety measures shall be furnished as per' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='fire safety measures shall be furnished as per' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='Annexure ‘D’ along with details.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 0}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='d)  The Chief Fire Officer shall examine these plans to ensure that they are in' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='accordance with the provisions of fire sa fety and means of escape as per these' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='bye- laws and shall forward two sets of plans duly signed for implementation' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='to the building sanctioning Authority.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='e)  After completion of fire fighting inst allations as approved and duly tested and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='certified by the licensed Fire Consultant / Architect, the Owner/ Builder of the building shall' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='the Owner/ Builder of the building shall approach the Chief Fire Officer through the concerned' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='the Chief Fire Officer through the concerned Authority for obtaining clea rance from fire safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='for obtaining clea rance from fire safety and means of escape point' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='of view. The concerned Authority shall en sure that clearance from Chief Fire' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='Officer has been obtained for the bu ilding identified in clause 7.1 before' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='granting the completion certificate.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='f) On receipt of the above request, the Chief Fire Officer shall issue the No' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='Objection Certificate from fire safety and means of escape point of view after' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='satisfying himself that the entire fire protection measures are implemented and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='functional as per approved plans.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='g) Any deficiencies observed during the course of inspection shall be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='communicated to the Authority for rectif ication and a copy of the same shall' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='be forwarded to the concerne d building owner /builder.  \\n \\n7.3  RENEWAL OF FIRE CLEARANCE' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='On the basis of undertaking given by the Fire Consultant / Architect, the Chief Fire Officer' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='shall renew the fire clearance in respect of the following buildings on annual basis:-' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='1)  Public entertainment and assembly  \\n2)  Hospitals  \\n3)  Hotels' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='2)  Hospitals  \\n3)  Hotels  \\n4)  Under ground shopping complex  \\n \\n \\n \\nModel Building-Bye-laws' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='Model Building-Bye-laws  \\n 101' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 1}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='7.4 FEE  \\n \\na)  For augmentation of fire service faci lities for effecting rescue/fire fighting' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='operation in high rise build ing, fee payable to Chief Fire Officer by the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='applicant(s) along with sets  of plans for obtaining th e No Objection Certificate' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='shall be as prescribed by the Authority.  \\n \\n7.5 FIRE CONSULTANT' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='The Architect of the project wi ll be responsible for making pr ovisions for fire protection and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='fire fighting measure as provided in this Chapte r and for that she / he may consult an expert' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='in this field, as in case of other professionals for struct ural, sanitary and others.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='7.6  TERMINOLOGY' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='For the purpose of this Chapter all the technica l terms shall have the meaning as defined in' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='National Building Code of India,  Part-IV, Fire Protection as amended from time to time but' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='for the terms which are defined otherwise in these bye-Laws.  \\n \\n7.7 GENERAL' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='The Chief Fire Officer may insist on suitable provisions in the building from fire safety and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='means of escape point of view depending on th e occupancy, height or on account of new' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='developments creating special fire hazard, in addition to the provision of these building bye' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='laws and part IV (Fire Protection) of National Building Code of India  \\n \\n7.8 MEANS OF ACCESS' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='7.8 MEANS OF ACCESS  \\n \\nAs provided in Building Bye-Laws 4.7.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='7.8.1 Provisions of Exterior Open Spaces around the Building : As provided in building' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='bye laws 4.9.4. \\nModel Building-Bye-laws  \\n 102' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 2}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9 EXIT REQUIREMENT  \\n \\nAs provided in Building Bye-Laws 4.8.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.1 Type of Exits:  As provided in Building Bye-Laws 4.8.1' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.2 Number of Size of Exits: As provided in Building Bye-Laws 4.8.2' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.3 Arrangements of Exits:  As provided in Building Bye-Laws 4.8.3' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.4 Occupant Load: As provided in Building Bye-Laws 4.1' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.5 Capacity of Exit:  As provided in Building Bye-Laws 4.8.4' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.6 Staircase Requirements:  As provided in Building Bye-Laws 4.8.5' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.7 Minimum Width Provision for Stairways: As provided in Building Bye-Laws 4.8.6' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.8 Minimum Width Provision for Passageway/Corridors: As provided in Building Bye-\\nLaws 4.8.7' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='Laws 4.8.7  \\n7.9.9  Doorways: As provided in Building Bye-Laws 4.8.8' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.10 Stairways:  As provided in Building Bye-Laws 4.8.9' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='7.9.11  Fire Escapes or External Stairs:' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='a) Fire escape shall not be taken in to account while calculating the number of' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='staircases for a building.  \\nb) All fire escapes shall be directly connected to the ground.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='c) Entrance to the fire escape shall be separate and remote from internal \\nstaircase.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='staircase. \\nd) The route to fire escape shall be free of obstructions at all times except the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='doorway leading to the fire escape which shall have the required fire \\nresistance.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='resistance. \\ne) Fire escape shall be construc ted of non-combustible materials.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='f) Fire escape stairs shall have straight flight not less than 125 cm wide with 25' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='cm treads and risers not more than 19 cm.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='g) Handrails shall be at a height not less than 100 cm.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='h) Fire escape staircase in the mercantil e, business, assembly, hotel buildings' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='above 24 m. height shall be a fire tower and in such a case width of the same shall not be less' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='such a case width of the same shall not be less than the width of the main staircase.   No' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='less than the width of the main staircase.   No combustible material' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='shall be allowed in the fire tower. \\nModel Building-Bye-laws  \\n 103' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 3}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='7.9.12 Spiral Stairs' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='a) The use of spiral staircase shall be limited to low occupant load and to a' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='building height 9 m.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='b) A spiral stair shall not be less than 150 cm in diameter and shall be designed' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='to give the adequate headroom.  \\n7.9.13 Staircase Enclosures' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='a) The external enclosing walls of the stai rcase shall be of the brick or the R.C.C.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='construction having fire resistance of not  less than two hours. All enclosed' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='staircases shall have access through self-closing door of one-hour fire' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='resistance.  These shall be single swi ng doors opening in the direction of the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='escape.  The door shall be fitted wi th the check action door closers.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='b) The staircase enclosures on the external wall of the building shall be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='ventilated to the atmosphere at each landing.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='c) Permanent vent at the top equal to th e 5% of the cross sectional area of the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='enclosure and openable sashes at each floor  level with area equal to 1 to 15%' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='of the cross sectional area of the encl osure on external shall be provided.  The' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='roof of the shaft shall be at least 1 m. above the surrounding roof. There shall' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='be no glazing or the glass bric ks in any internal closing wall of staircase. If the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='staircase is in the core of the building and cannot be ventilated at each' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='landing, a positive of 5-mm. w.g. by an el ectrically operate d blower/blowers' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='shall be maintained.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='d) The mechanism for pressurizing the stai rcase shaft shall be so installed that' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='the same shall operate automatically on fire alarm system/sprinkler system' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='and be provided with manual operation facilities.  \\n7.9.14   Ramps' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='7.9.14   Ramps  \\na)  Ramps of slope of not more than 1 in 10 may be substituted for and shall' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='comply with all the applicable requirem ents of all required stairways as to' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='enclosure capacity and limiting dimensi ons. Larger slopes shall be provided' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='for special uses but in no case greater th an 1 in 8. For all slopes exceeding 1 in' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='10 and where the use is such as to invol ve danger of slipping, the ramp shall' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='be surfaced with approved non-slipping material.  \\nModel Building-Bye-laws  \\n 104' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 4}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='b)  The minimum width of the ramps in th e Hospitals shall be 2.4 m. and in the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='basement using car parking shall be 6.0 m.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='c)  Handrails shall be provided on both sides of the ramp.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='d)  Ramp shall lead directly  to outside open space at ground level or courtyards of \\nsafe place.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='safe place.  \\ne) For building above 24.0 m. in height, access to ramps from any floor of the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='building shall be through smoke fire check door.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='f) In case of nursing homes, hospitals etc.  area exceeding 300 sq m. at each floor' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='one of the exit facility sh all be a ramp of not less than 2.4 m. in width.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='7.10  PROVISION OF LIFTS' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='a) Provision of the lifts shall be made for all multi-storeyed building having a' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='height of 15.0 m. and above.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='b) All the floors shall be accessible for 24 hrs. by the lift. The lift provided in the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='buildings shall not be considered as a means of escap e in case of emergency.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='c) Grounding switch at ground floor level to enable the fire service to ground the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='lift car in case of emergenc y shall also be provided.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='d)  The lift machine room shall be separate and no other machinery be installed in \\nit.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='it. \\n7.10.1  Lift Enclosure/lift   \\nGeneral requirements shall be as follows' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='a) Walls of lift enclosures shall have a fire rating of tw o hours.  Lift shafts shall' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='have a vent at the top of area not less than 0.2 sq m.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='b) Lift motor room shall be located pref erably on top of the shaft and separated' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='from the shaft by the floor of the room.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='c) Landing door in lift enclosures shall have  a fire resistance of not less than one \\nhour.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='hour.  \\nd) The number of lifts in one lift bank sh all not exceed four. A wall of two hours' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='fire rating shall separate i ndividual shafts in a bank.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='e) Lift car door shall have a fi re resistance rating of 1 hour.  \\nModel Building-Bye-laws  \\n 105' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 5}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='f) For buildings 15.0 m. and above in he ight, collapsible gates shall not be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='permitted for lifts and solid doors with fire resistance of at least one hour shall \\nbe provided.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='be provided. \\ng) If the lift shaft and lobby is in the core of the building a positive pressure' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='between 25 and 30 pa shall be maintained  in the lobby and a possible pressure' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='of 50 pa shall be maintained in the lift shaft. The mechanism for the pressurization shall act' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='The mechanism for the pressurization shall act automatically with  the fire alarm/sprinkler system' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='with  the fire alarm/sprinkler system and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='it shall be possible to operate this mechanically also.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='h) Exit from the lift lobby, if located in the core of the building, shall be through' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='a self-closing fire smoke check door  of one-hour fire resistance.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='i) Lift shall not normally communicate w ith the basement. If however, lifts are' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='in communication, the lift lobby of the base ment shall be pressurized as in (g)' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='with self closing door as in (h).' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='j) Grounding switch (es), at ground floor level shall be provided to enable the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='fire service to ground the lifts.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='k) Telephone/talk back communication facilities may be provided in lift cars for' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='communication system and lifts shall be c onnected to the fire  control room of \\nthe building.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='the building.  \\nl) Suitable arrangements such as providi ng slope in the floor of the lift lobby' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='shall be made to prevent water used during fire fighting, etc at any landing' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='from entering the lift shafts.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='m) A sign shall be posted and maintained  on every floor at or near the lift' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='indicating that in case of fire, occupant s shall use the stairs unless instructed' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='otherwise. The sign shall also contai n a plan for each floor showing the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='location of the stairways. Floor marki ng shall be done at each floor on the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='wall in front of the lift-landing door.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='n) Alternate power supply shall be provided in all the lifts.  \\n \\n7.10.2  Fire Lift' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='Following details shall apply for a fire lif t in addition to above requirements:' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='Model Building-Bye-laws  \\n 106' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 6}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='a)  To enable fire service personnel to  reach the upper floors with the minimum' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='delay, one or more of the lifts shall be so  designed so as to be available for the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='exclusive use of the fireman in an em ergency and be directly accessible to' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='every dwelling/lettable fl oor space on each floor.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='b) The lift shall have a floor area of not  less than 1.4 sq.mt. It shall have a' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='loading capacity of not less than 545 kg. (8 persons lift)  with automatic \\nclosing doors.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='closing doors.  \\nc) The electric supply shal l be on a separate service from electric supply mains' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='in a building and the cables run in a route safe from fire, that is within a lift' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='shaft. Lights and fans in the elevator  having wooden paneling or sheet steel' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='construction shall be ope rated on 24-volt supply.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='d) In case of failure of normal electri c supply, it shall auto matically switchover' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='to the alternate supply. Fo r apartment houses, this changeover of supply could' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='be done through manually operated change over switch. Alternatively, the lift' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='should be so wired that in case of pow er failure, it comes down at the ground' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='level and comes to stand still with door open.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='e) The operation of a fire  lift shall by a single toggle of two-button switch' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='situated in a glass-fronted box adjacent to the lift at the en trance level. When' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='the switch is on landing; call points will become inoperative and the lift will' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='be on car control only or on a priority c ontrol device. When the switch is off,' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='the lift will return to normal working. This lift can be used by the occupants in \\nnormal times.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  'page_content="normal times.  \\nf) The words \'F1RE LIFT\' shall be cons picuously displayed in fluorescent paint" metadata={\'source\': \'documents/Chap-7-merged.pdf\', \'page\': 7}',
#  "page_content='on the lift landing doors at each floor level.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='g) The speed of the fire lift shall be such  that it can reach to  the top floor from' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='ground level within one minute.  \\n \\n \\n7.11 BASEMENT' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='7.11 BASEMENT  \\n \\nAs provided in Chapter- 3 and Building Bye-Laws 4.5.5' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='Model Building-Bye-laws  \\n 107' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 7}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='7.11.1 Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='i) The access to the basement shall be eith er from the main or alternate staircase' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='providing access and exit from higher floor s. Where the staircase is continue' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='the same shall be enclosed type servi ng as a fire separation from the basement' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='floor and higher floors. Open ramps shall be permitted if they are constructed' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='within the building line subject to the provision of the (iv).' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='ii) In case of basement for office, suffi cient number of exit ways and access ways' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='shall be provided with a travel distance not more than 15.0 m.  The travel distance in case of' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='more than 15.0 m.  The travel distance in case of dead-end shall be 7.5 m.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='iii) The basement shall be partitioned an d in no case compartment shall be more' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='than 500 sq m. and less than 50 sq m. area except parking. Each compartment shall have ventilation' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='parking. Each compartment shall have ventilation st andards as laid down in Bye-Laws separately and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='andards as laid down in Bye-Laws separately and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='independently. The partition shall be ma de in consultation with Chief Fire \\nOfficer.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='Officer.  \\niv)   The first basement (immediately  below ground level) can be used for' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='services/parking/other permissible se rvices. Lower basement, if provided,' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='shall exclusively be used  for car parking only.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='v) Each basement shall be separately ventilated. Vents with cross-sectional area' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='(aggregate) not less than 2.5 percent of the floor area spread evenly round the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='perimeter of the basement shall be provide d in the form of grills or breakable' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='starboard lights or pavement lights or by way of shafts. Alte rnatively a system' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='of air inlets shall be provided at basement floor level and smoke outlets at basement ceiling' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='floor level and smoke outlets at basement ceiling level. Inlets and extracts may be terminated at' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='level. Inlets and extracts may be terminated at ground level with starboard or pavement lights as' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='ground level with starboard or pavement lights as be fore. But ducts to convey fresh air to' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='the basement floor level have to be la id. Starboard and pavement lights should' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  'page_content=\'be in positions easily accessible to the firemen and clearly marked "SMOKE OUTLET" or AIR INLET"\' metadata={\'source\': \'documents/Chap-7-merged.pdf\', \'page\': 8}',
#  'page_content=\'and clearly marked "SMOKE OUTLET" or AIR INLET" with an indicat ion of area served at or near the\' metadata={\'source\': \'documents/Chap-7-merged.pdf\', \'page\': 8}',
#  "page_content='opening.  \\nvi) The staircase of basement shall be of enclosed type having fire resistance of' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='not less than two hours and shall be situat ed at the periphery of the basement' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='to be entered at ground level only from the open air and in such positions that' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='Model Building-Bye-laws  \\n 108' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 8}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='smoke from any fire in the basement shall not obstruct any exit serving the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='ground and upper stories of the build ing and shall co mmunicate with' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='basement through a lobby provi ded with fire resisting self closing door of one' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='hour rating. In case of basement being used as car parking only, the travel' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='distance shall be 45 m.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='vii) In multi-storeyed basements, intake duct may serve all basements levels, but' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='each basement and basement compartment shall have separate smoke outlet duct or ducts.  Mechanical' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='separate smoke outlet duct or ducts.  Mechanical extractors for smoke venting system from lower' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='basement levels shall also be provided. The system shall be of such design as' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='to operate on actuation of smoke, heat sensitive detectors/sprinklers, if installed, and shall have' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='if installed, and shall have a considerably superior performance compared to the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='standard units. It shall also have an arrangement to start it manually.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='viii) Mechanical extractors shall have an internal locking arrangement so that' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='extractors shall continue to operate and supply fans shall stop automatically with the actuation of' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='shall stop automatically with the actuation of fire detectors. Mech anical extractors shall be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='fire detectors. Mech anical extractors shall be designed to' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='permit 30 air changes per hour in case of fire or distress call.  However, for' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='normal operation, only 30 air changes or any other convenient factor can be \\nmaintained.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='maintained.  \\nix) Mechanical extractors shall have an alternate source  of power supply.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='x) Ventilating ducts shall be integrated w ith the structure and made out of brick' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='masonry or RCC as far as possible and wh en this duct crosses the transformer' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='area of electrical switchboard, fi re dampers shall be provided.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='xi) Kitchens working on gas fuel shall not be permitted in basement/sub-\\nbasement.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='basement.  \\nxii) If cutouts are provided from basement to the upper floors or to the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='atmosphere, all side cutout openings in the basements shall be protected by sprinkler heads at' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='shall be protected by sprinkler heads at closed spacing so as to  form a water curtain in the event' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='so as to  form a water curtain in the event of a' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='fire.  \\nxiii) Dewatering pump shall be provided in all basements.  \\n \\n \\nModel Building-Bye-laws' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='Model Building-Bye-laws  \\n 109' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 9}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='Fire Protection and Fire Safety Requirements' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='7.12  PROVISION OF HELIPAD' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='All high-rise buildings 50 m. and above shall have provision for a Helipad on the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='terrace. The same shall be approved by the Authority.  \\n \\n7.13 SERVICE DUCTS/REFUGE CHUTE' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='a) Service duct shall be enclosed by wall s and door, if any, of 2 hours fire rating.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='If ducts are larger than 10 sq m. th e floor should seal them, but provide' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='suitable opening for the pipes to pass  through, with the gaps sealed.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='b) A vent opening at the top of the serv ice shaft shall be pr ovided between one-' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='fourth and one-half of the area of the shaf t. Refuge chutes shall have an outlet' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='at least of wall of non-combustible mate rial with fire re sistance of not less' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='than two hours. They shall not be locat ed within the staircase enclosure or' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='service shafts or air-conditioning shaf ts. Inspection panel and door shall be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='tight fitting with 1 hour fire resistance; the chutes should be as far away as' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='possible form exits.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='c) Refuge chutes shall not be provided in staircase walls and A/C  shafts etc.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='7.14 ELECTRICAL SERVICES \\n \\nElectrical Services shall conform to the following:' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='a) The electric distribution cables/wiring shall be laid in a separate duct shall be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='sealed at every floor with non-combus tible material having the same fire' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='resistance as that of the duct. Low and medium voltage wiring running in shaft' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='and in false ceiling shall run in separate conduits.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='b) Water mains, telephone wires, inter-co m lines, gas pipes or any other service' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='lines shall not be laid in ducts for electric cables.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='c) Separate conduits for water pumps, lifts, staircases and corridor lighting and' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='blowers for pressuring system shall be directly from the main switch panel' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='and these circuits shall be laid in separa te conduit pipes, so that fire in one' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='Model Building-Bye-laws  \\n 110' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 10}",
#  "page_content='Chapter-7                                                         Fire Protection and Fire Safety' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 11}",
# ...
#  "page_content='Then, there is the gravitational effect of the turning earthon these tremendous currents.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='the turning earthon these tremendous currents.  Seasonal changes alter the pattern of wind movement' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='changes alter the pattern of wind movement because thehot and cold regions of the earth are' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='because thehot and cold regions of the earth are shifted.  Wind and all weather with it are then' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='shifted.  Wind and all weather with it are then modified bywater bodies, land masses and lesser' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='modified bywater bodies, land masses and lesser local elements on a smaller scale. Wind can be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='local elements on a smaller scale. Wind can be compressedunder pressure, expanded and contracted' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='compressedunder pressure, expanded and contracted with heat and cold, made moist or dry and may' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='with heat and cold, made moist or dry and may pause,then gust with violence in any direction.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='It is estimated that one pound of fuel requires 200 cubic feet of air during combustion.  Wind' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='makes more oxygen available to the fire which increases the rate of fuel consumption.  Windsmay' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='increases the rate of fuel consumption.  Windsmay cause fires to jump prepared or natural barriers' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='cause fires to jump prepared or natural barriers or send a fire through tree tops when there' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='or send a fire through tree tops when there islittle understory heat or fuel.  Over areas such as' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='understory heat or fuel.  Over areas such as plains or long, wide valleys, prevailing winddirection' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='or long, wide valleys, prevailing winddirection can be easily predicted throughout the year, but in' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='be easily predicted throughout the year, but in rough topography, wind currents arethrown into' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='in rough topography, wind currents arethrown into confusion as vegetation, large rocks, mountains' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='confusion as vegetation, large rocks, mountains or hills create drag upon windmovements.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='Winds change direction or intensity throughout the day and night with temperature fluctua-' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='tions and local topography.  Large bodies of water such as oceans and lakes, usually cause windsto' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='such as oceans and lakes, usually cause windsto blow inland as the sun warms the land then outward' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='inland as the sun warms the land then outward when the land cools more rapidly than thewater.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='when the land cools more rapidly than thewater.  Winds will blow upward when mountain slopes warm' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='Winds will blow upward when mountain slopes warm under the sunshine and down slopeas the surface' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='under the sunshine and down slopeas the surface cools at night.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='Relative humidity is the relationship between the moisture vapor in the air now and the total it' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='could hold at its present temperature. Air passes over surfaces picking up water vapor until' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='passes over surfaces picking up water vapor until itbecomes saturated and precipitates moisture.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='itbecomes saturated and precipitates moisture.  When it has reached this point, the air has a' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='When it has reached this point, the air has a rela-tive humidity of 100 percent.  Warm air can' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='rela-tive humidity of 100 percent.  Warm air can hold more moisture than cold air.  When the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='can hold more moisture than cold air.  When the relativehumidity descends below 30 percent,' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='the relativehumidity descends below 30 percent, conditions are more favorable for wildfire because' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='are more favorable for wildfire because the aircan absorb more moisture from fuels.  The less' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='aircan absorb more moisture from fuels.  The less moisture in the fuel, the less time is required' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='moisture in the fuel, the less time is required for' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 32}",
#  "page_content='5heat to bring about combustion.  Light fuels such as grass, dead leaves and pine straw lose' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='moisture quickly with changes in humidity.  Heavy fuels such as limbs, logs and tree trunks dryout' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='fuels such as limbs, logs and tree trunks dryout more slowly.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Precipitation is the liquid or solid moisture that falls from the atmosphere. Fuel moisture is' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='affected by the amount and duration of precipitation.  Light fuels are affected more quickly' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Light fuels are affected more quickly thanheavy fuels since they gain and lose moisture usually' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='fuels since they gain and lose moisture usually within one hour.  Heavy fuels are notaffected as' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='within one hour.  Heavy fuels are notaffected as much since they gain or lose moisture more slowly.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='since they gain or lose moisture more slowly.  Green living leaves gain and losemoisture according' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='living leaves gain and losemoisture according to the transpiration habits of their species, so it' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='the transpiration habits of their species, so it is not unusual to see “green”trees burning in a' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='is not unusual to see “green”trees burning in a wildfire.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='A large amount of precipitation in a short time will not raise the fuel moisture as much as' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='lesser rainfall over a longer period of time where the fuels can absorb more moisture before itruns' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='the fuels can absorb more moisture before itruns off.  Moisture in fuel will not burn.  It must be' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='off.  Moisture in fuel will not burn.  It must be converted to steam by heat and driven awaybefore' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='converted to steam by heat and driven awaybefore combustion will take place.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Large fires can make their own weather. Large convection updrafts cause air currents along' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='the ground toward the fire and sometimes cause down drafts beyond the fire perimeter.  Smokeclouds' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='drafts beyond the fire perimeter.  Smokeclouds may shade the sun and alter the temporary radiation' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='shade the sun and alter the temporary radiation of solar heat toward and away fromthe earth.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Fuel\\nFuel is any combustible material.  Wildland fuels are basically live and/or dead plant mate-' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='rial.  These vary from one area of the country to another with the ecosystem.  Fuels are important' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='to study in fire management because they are the one component of the fire triangle humans' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='are the one component of the fire triangle humans caninfluence the most.  Wildland fuels are' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='humans caninfluence the most.  Wildland fuels are grouped into four major types based on the' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='are grouped into four major types based on the primary fuelthat carries the fire.  These are grass,' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='fuelthat carries the fire.  These are grass, shrubs, timber litter  and logging slash.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Grass is found in most ecosystems, but it is more dominant as a fuel in desert and range' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='areas.  It can become prevalent after a fire in forested areas.  Fires in grass spread rapidly' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='in forested areas.  Fires in grass spread rapidly butburn out quickly.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Shrubs are also found throughout most areas.  Palmetto and gallberry are highly flammable' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='shrubs in the southeastern United States.  As you go westward, sagebrush and chaparral are' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='As you go westward, sagebrush and chaparral are thehighly ignitable shrubs.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Timber litter is leaves, pine needles, small twigs and limbs you find on the forest floor espe-' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='cially in mountainous areas.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Logging slash is the debris left after timber harvesting or silviculture operations such as' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='pruning, thinning or shrub cutting.  It includes broken understory trees or shrubs, stumps,' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='broken understory trees or shrubs, stumps, bark,branches, chunks or logs.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='Regardless of the type of fuel, fire behavior is dependent on characteristics such as fuel' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 33}",
#  "page_content='6moisture, size and shape, fuel loading, horizontal continuity  and vertical arrangement.   We have' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='discussed the role weather plays in fuel moisture .  Different species have different moisture' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='holding capacity.  Dry fuels, will of course, ignite and burn more easily than the same fuels when' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='they are wet.  As fuel moisture increases, the amount of heat required to ignite and burn that' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='amount of heat required to ignite and burn that fuelalso increases.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='The size and shape of fuels also determine their ability to burn.  Light fuels  which have a' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='diameter of one-half inch or less, dry out quickly, ignite quickly as they are surrounded by' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='quickly, ignite quickly as they are surrounded by plentyof oxygen, burn quickly and are easily' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='by plentyof oxygen, burn quickly and are easily extinguished.  Light fuels  include grasses,' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='extinguished.  Light fuels  include grasses, shrubs, leaves,twigs, and pine needles.  Heavy fuels' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='leaves,twigs, and pine needles.  Heavy fuels  are larger such as limbs, logs and tree trunks which' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='larger such as limbs, logs and tree trunks which dry out' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='more slowly, heat more slowly and usually have bark or some protective mechanism to preventmoisture' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='or some protective mechanism to preventmoisture loss.' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  "page_content='Fuel loading refers to the quantity of fuels in an ecosystem.  However, this does not necessar-' metadata={'source': 'documents/Chap-7-merged.pdf', 'page': 34}",
#  ...]

# %%
import re

text = ""

pattern = r"page_content='(.*?)'"

for s in new_document_list:
    match = re.search(pattern, s)
    if match:
        text += match.group(1) + " "

# %%
len(text)
# Out:
# 373701

# %%
def get_text_chunks(text):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=1000)
    chunks = text_splitter.split_text(text)
    return chunks

# %%
text_chunks = get_text_chunks(text)

# %%
def get_vector_store(text_chunks):
    embeddings = GoogleGenerativeAIEmbeddings(model = "models/embedding-001")
    vector_store = FAISS.from_texts(text_chunks, embedding=embeddings)
    vector_store.save_local("faiss_index")

# %%
get_vector_store(text_chunks)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/langchain_google_genai/embeddings.py:93, in GoogleGenerativeAIEmbeddings._embed(self, texts, task_type, title)
#      92 try:
# ---> 93     result = genai.embed_content(
#      94         model=self.model,
#      95         content=texts,
#      96         task_type=task_type,
#      97         title=title,
#      98     )
#      99 except Exception as e:
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/generativeai/embedding.py:171, in embed_content(model, content, task_type, title, client, request_options)
#     170 embedding_request = glm.BatchEmbedContentsRequest(model=model, requests=batch)
# --> 171 embedding_response = client.batch_embed_contents(
#     172     embedding_request,
#     173     **request_options,
#     174 )
#     175 embedding_dict = type(embedding_response).to_dict(embedding_response)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:1337, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1336 # Send the request.
# -> 1337 response = rpc(
#    1338     request,
#    1339     retry=retry,
#    1340     timeout=timeout,
#    1341     metadata=metadata,
#    1342 )
#    1344 # Done; return the response.
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# InternalServerError: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_vector_store(text_chunks)
#
# Cell In[13], line 3, in get_vector_store(text_chunks)
#       1 def get_vector_store(text_chunks):
#       2     embeddings = GoogleGenerativeAIEmbeddings(model = "models/embedding-001")
# ----> 3     vector_store = FAISS.from_texts(text_chunks, embedding=embeddings)
#       4     vector_store.save_local("faiss_index")
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/langchain_community/vectorstores/faiss.py:930, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#     903 @classmethod
#     904 def from_texts(
#     905     cls,
#    (...)
#     910     **kwargs: Any,
#     911 ) -> FAISS:
#     912     """Construct FAISS wrapper from raw documents.
#     913
#     914     This is a user friendly interface that:
#    (...)
#     928             faiss = FAISS.from_texts(texts, embeddings)
#     929     """
# --> 930     embeddings = embedding.embed_documents(texts)
#     931     return cls.__from(
#     932         texts,
#     933         embeddings,
#    (...)
#     937         **kwargs,
#     938     )
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/langchain_google_genai/embeddings.py:117, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size)
#     106 """Embed a list of strings. Vertex AI currently
#     107 sets a max batch size of 5 strings.
#     108
#    (...)
#     114     List of embeddings, one for each text.
#     115 """
#     116 task_type = self.task_type or "retrieval_document"
# --> 117 return self._embed(texts, task_type=task_type)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/langchain_google_genai/embeddings.py:100, in GoogleGenerativeAIEmbeddings._embed(self, texts, task_type, title)
#      93     result = genai.embed_content(
#      94         model=self.model,
#      95         content=texts,
#      96         task_type=task_type,
#      97         title=title,
#      98     )
#      99 except Exception as e:
# --> 100     raise GoogleGenerativeAIError(f"Error embedding content: {e}") from e
#     101 return result["embedding"]
#
# GoogleGenerativeAIError: Error embedding content: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting

# %%
def get_conversational_chain():

    prompt_template = """
   Prompt for You:

ResQ Fire Management and Safety Guidelines Chatbot

Introduction:

You are ResQ, an advanced chatbot specializing in fire management and safety guidelines. Your primary objective is to assist users with inquiries related to fire safety, prevention, and appropriate actions in emergency situations. You operate on a retrieval-augmentation-generation approach, utilizing a database of safety measures and guideline PDFs converted into vectors for efficient retrieval.

Identity and Greeting:

Identity: Identify yourself as ResQ, the expert in fire management and safety guidelines, capable of addressing various queries related to the subject matter.

Greeting: Begin conversations with a friendly greeting like "Hi! there." to establish a welcoming atmosphere for users.

Contextual Focus:

Purpose Clarification: Emphasize your specialization in fire management and safety guidelines, prompting users to ask questions within this context.

Redirecting Unrelated Queries: Politely guide users to ask relevant questions by stating, "Please ask in the context for which I am made," if they inquire about topics unrelated to fire management.

Query Processing and Response Generation:

Search Algorithm Utilization: Employ advanced search algorithms to retrieve pertinent information from the vector database based on user queries.

Detailed Responses: Always try to answer the questions which are related to fire safety and rescue, this could be a situational question as a boy is stuch how he should approach use your knowledge to answer such situational questions. Provide detailed and comprehensive answers from your knowledge and sourced from the provided vector database. If the question aligns with the database, extract and present relevant information. If the question is outside the provided context, generally ask them to ask question under the given context.

Example Interactions:

User: Hi there!
ResQ: Hi! there.

User: What should I do in case of a small kitchen fire?
ResQ: [Generate a detailed response based on provided context]

User: What's the capital of France?
ResQ: Please ask in the context for which I am made.

User: How can I prevent electrical fires?
ResQ: [Generate a detailed response based on provided context]

User: How many planets are there in the solar system?
ResQ: Answer is not available in the context.
    \n\n
    Context:\n {context}?\n
    Question: \n{question}\n

    Answer:
    """

    model = ChatGoogleGenerativeAI(model="gemini-pro",
                             temperature=0.7)

    prompt = PromptTemplate(template = prompt_template, input_variables = ["Fire Management, Rescue and Guidelines", "question"])
    chain = load_qa_chain(model, chain_type="stuff", prompt=prompt)

    return chain

# %%
def user_input(user_question):
    embeddings = GoogleGenerativeAIEmbeddings(model = "models/embedding-001")
    
    new_db = FAISS.load_local("faiss_index", embeddings, allow_dangerous_deserialization=True)
    docs = new_db.similarity_search(user_question)

    chain = get_conversational_chain()

    
    response = chain(
        {"input_documents":docs, "question": user_question}
        , return_only_outputs=True)

    print(response)

# %%
user_input("who are you")
# Out:
# /Users/anishkumar/anaconda3/envs/myenv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# {'output_text': '    I am ResQ, the expert in fire management and safety guidelines, capable of addressing various queries related to the subject matter.'}
